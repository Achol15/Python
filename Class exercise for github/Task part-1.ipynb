# %% [markdown]
# # **Function**

# %% [markdown]
#  **1**

# %%
def calculate_expression(a, b):
    return a**2 + b**2 + 2*a*b

a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))
result = calculate_expression(a, b)
print(f"The result of (a+b)^2 is: {result}")
# Out:
# Enter the value of a: 55
# Enter the value of b: 55
# The result of (a+b)^2 is: 12100

# %% [markdown]
# **2**

# %%
lambda_expression = lambda a, b: a**2 + b**2 + 2*a*b

a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))
result = lambda_expression(a, b)
print(f"The result of (a+b)^2 using lambda is: {result}")
# Out:
# Enter the value of a: 5
# Enter the value of b: 5
# The result of (a+b)^2 using lambda is: 100

# %% [markdown]
# **3**

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

n = int(input("Enter a number to find its factorial: "))
result = factorial(n)
print(f"The factorial of {n} is: {result}")
# Out:
# Enter a number to find its factorial: 5
# The factorial of 5 is: 120

# %% [markdown]
# **4**

# %%
def is_prime(num):
    if num <= 1:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

num = int(input("Enter a number to check if it is prime: "))
if is_prime(num):
    print(f"{num} is a prime number.")
else:
    print(f"{num} is not a prime number.")
# Out:
# Enter a number to check if it is prime: 12
# 12 is not a prime number.

# %% [markdown]
# ### **List**

# %% [markdown]
# **1**

# %%
a = [1, 3, 5, 7, 9]

print("a[-2]:", a[-2])
print("a[2]:", a[2])
print("Length of a:", len(a))
print("Type of a:", type(a))
# Out:
# a[-2]: 7
# a[2]: 5
# Length of a: 5
# Type of a: <class 'list'>

# %% [markdown]
# **2**

# %%
a = [1, 3, 5, 7, 9]

a[-3] = 50

print("After changing a[3]:", a)
print("a[2:4]:", a[2:4])
# Out:
# After changing a[3]: [1, 3, 50, 7, 9]
# a[2:4]: [50, 7]

# %% [markdown]
#  **3**

# %%
a = [1, 3, 5, 7, 9]

a.append(100)
print("After appending 100:", a)

a.insert(2, 200)
print("After inserting 200 at index 2:", a)
# Out:
# After appending 100: [1, 3, 5, 7, 9, 100]
# After inserting 200 at index 2: [1, 3, 200, 5, 7, 9, 100]

# %% [markdown]
# **4**

# %%
a = [1, 3, 5, 7, 9]

a.pop()
print("After removing last element:", a)

a.pop(1)
print("After removing element at index 1:", a)
# Out:
# After removing last element: [1, 3, 5, 7]
# After removing element at index 1: [1, 5, 7]

# %% [markdown]
# **5**

# %%
a = [1, 3, 5, 7, 9]

new_list = [2, 4, 6]
a.extend(new_list)
print("After joining new list:", a)
# Out:
# After joining new list: [1, 3, 5, 7, 9, 2, 4, 6]

# %% [markdown]
# **6**

# %%
a = [1, 3, 5, 7, 9]

new_list = [2, 4, 6]
a.extend(new_list)
print("After joining new list: ", a)

b = a.copy()
print("Copied list b:", b)
# Out:
# After joining new list:  [1, 3, 5, 7, 9, 2, 4, 6]
# Copied list b: [1, 3, 5, 7, 9, 2, 4, 6]

# %% [markdown]
# **7**

# %%
a = [1, 3, 5, 7, 9]

new_list = [2, 4, 6]
a.extend(new_list)
print("After joining new list: ", a)

b = a.copy()
print("Copied list b:", b)
b.sort()
print("Sorted list b:", b)
# Out:
# After joining new list:  [1, 3, 5, 7, 9, 2, 4, 6]
# Copied list b: [1, 3, 5, 7, 9, 2, 4, 6]
# Sorted list b: [1, 2, 3, 4, 5, 6, 7, 9]

# %% [markdown]
# **8**

# %%
a = [1, 3, 5, 7, 9]

print("Printing elements until 5:")
for element in a:
    if element == 5:
        print(element)
        break
    print(element)
# Out:
# Printing elements until 5:
# 1
# 3
# 5

# %% [markdown]
# **9**

# %%
a = [1, 3, 5, 7, 9]

largest = max(a)
print("Largest number in a:", largest)
# Out:
# Largest number in a: 9

# %% [markdown]
# ## **Tuple**

# %% [markdown]
# **a**

# %%
a = (1, 3, 5, 7, 4)

sum_of_odds = sum(x for x in a if x % 2 != 0)
print("Sum of all odd numbers:", sum_of_odds)
# Out:
# Sum of all odd numbers: 16

# %% [markdown]
# **b**

# %%
a = (1, 3, 5, 7, 4)

for i, value in enumerate(a):
    print(f"Element {value} is at index {i}")
# Out:
# Element 1 is at index 0
# Element 3 is at index 1
# Element 5 is at index 2
# Element 7 is at index 3
# Element 4 is at index 4

# %% [markdown]
# **c**

# %%
a = (1, 3, 5, 7, 4)

odd_count = sum(1 for x in a if x % 2 != 0)
even_count = sum(1 for x in a if x % 2 == 0)

print("Total odd numbers:", odd_count)
print("Total even numbers:", even_count)
# Out:
# Total odd numbers: 4
# Total even numbers: 1

# %% [markdown]
# **d**

# %%
a = (1, 3, 5, 7, 4)

a = a + (2, 4, 6)
print("Extended tuple:", a)
# Out:
# Extended tuple: (1, 3, 5, 7, 4, 2, 4, 6)

# %% [markdown]
# **e**

# %%
a = (1, 3, 5, 7, 4)

a_list = list(a)
a_list.insert(2, 400)
a = tuple(a_list)

print("Tuple after adding 400 at index 2:", a)
# Out:
# Tuple after adding 400 at index 2: (1, 3, 400, 5, 7, 4)

# %% [markdown]
# **f**

# %%
a = (1, 3, 5, 7, 4)

a_list = list(a)
a_list.pop()
a = tuple(a_list)
print("Tuple after removing the last element:", a)
# Out:
# Tuple after removing the last element: (1, 3, 5, 7)

# %% [markdown]
# **g**

# %%
a = (1, 3, 5, 7, 4)
sliced = a[-4::-1]

print("Slicing [-4::-1]:", sliced)
# Out:
# Slicing [-4::-1]: (3, 1)

# %% [markdown]
# **h**

# %%
a = (1, 3, 5, 7, 4)

print("Printing tuple and skipping 5:")

for value in a:
    if value == 5:
        continue
    print(value)
# Out:
# Printing tuple and skipping 5:
# 1
# 3
# 7
# 4

# %% [markdown]
# ### **Set**

# %% [markdown]
# **1**

# %%
a = {1, 3, 5, 8, 3, 7}
b = {0, False, 1, 5}

print("Set a:", a)
print("Set b:", b)
# Out:
# Set a: {1, 3, 5, 7, 8}
# Set b: {0, 1, 5}

# %% [markdown]
# **2**

# %%
a = {1, 3, 5, 8, 3, 7}
b = {0, False, 1, 5}

print("Length of a:", len(a))
print("Type of a:", type(a))

print("Length of b:", len(b))
print("Type of b:", type(b))
# Out:
# Length of a: 5
# Type of a: <class 'set'>
# Length of b: 3
# Type of b: <class 'set'>

# %% [markdown]
# **3**

# %%
a = {1, 3, 5, 8, 3, 7}

a.add(10)
print("Set a after adding 10:", a)
# Out:
# Set a after adding 10: {1, 3, 5, 7, 8, 10}

# %% [markdown]
# **4**

# %%
a = {1, 3, 5, 8, 3, 7}

a.discard(8)
print("Set a after removing 8:", a)
# Out:
# Set a after removing 8: {1, 3, 5, 7}

# %% [markdown]
# **5**

# %%
a = {1, 3, 5, 8, 3, 7}
b = {0, False, 1, 5}

union = a.union(b)
print("Union of a and b:", union)

intersection = a.intersection(b)
print("Intersection of a and b:", intersection)

difference = a.difference(b)
print("Difference of a and b (a - b):", difference)

symmetric_difference = a.symmetric_difference(b)
print("Symmetric difference of a and b:", symmetric_difference)

subset = a.issubset(b)
print("Is a a subset of b?:", subset)
# Out:
# Union of a and b: {0, 1, 3, 5, 7, 8}
# Intersection of a and b: {1, 5}
# Difference of a and b (a - b): {8, 3, 7}
# Symmetric difference of a and b: {0, 3, 7, 8}
# Is a a subset of b?: False

# %% [markdown]
# **6**

# %%
a = {1, 3, 5, 8, 3, 7}

new_list = [2, 3, 4]
a.update(new_list)
print("Set a after adding new list:", a)
# Out:
# Set a after adding new list: {1, 2, 3, 4, 5, 7, 8}

# %% [markdown]
# ## **Dictionary**

# %% [markdown]
# **1**

# %%
employee = {
    "name": "A",
    "age": 40,
    "type": {"developer": ["iOS", "android"]},
    "permanent": True,
    "salary": 30000,
    100: (1, 2, 3),
    4.5: {5, 6, "Tone", 7, 1}
}

print("Length of employee: ", len(employee))
print("Type of employee: ", type(employee))
# Out:
# Length of employee:  7
# Type of employee:  <class 'dict'>

# %% [markdown]
# **2**

# %%
employee = {
    "name": "A",
    "age": 40,
    "type": {"developer": ["iOS", "android"]},
    "permanent": True,
    "salary": 30000,
    100: (1, 2, 3),
    4.5: {5, 6, "Tone", 7, 1}
}

print("Accessing the developer key:", employee["type"]["developer"])
# Out:
# Accessing the developer key: ['iOS', 'android']

# %% [markdown]
# **3**

# %%
employee = {
    "name": "A",
    "age": 40,
    "type": {"developer": ["iOS", "android"]},
    "permanent": True,
    "salary": 30000,
    100: (1, 2, 3),
    4.5: {5, 6, "Tone", 7, 1}
}

employee["permanent"] = False
print("Updated 'permanent' to False:", employee)
# Out:
# Updated 'permanent' to False: {'name': 'A', 'age': 40, 'type': {'developer': ['iOS', 'android']}, 'permanent': False, 'salary': 30000, 100: (1, 2, 3), 4.5: {1, 5, 6, 7, 'Tone'}}

# %% [markdown]
# **4**

# %%
employee = {
    "name": "A",
    "age": 40,
    "type": {"developer": ["iOS", "android"]},
    "permanent": True,
    "salary": 30000,
    100: (1, 2, 3),
    4.5: {5, 6, "Tone", 7, 1}
}

employee["gender"] = "male"
print("Added 'gender':", employee)
# Out:
# Added 'gender': {'name': 'A', 'age': 40, 'type': {'developer': ['iOS', 'android']}, 'permanent': True, 'salary': 30000, 100: (1, 2, 3), 4.5: {1, 5, 6, 7, 'Tone'}, 'gender': 'male'}

# %% [markdown]
# **5**

# %%
employee = {
    "name": "A",
    "age": 40,
    "type": {"developer": ["iOS", "android"]},
    "permanent": True,
    "salary": 30000,
    100: (1, 2, 3),
    4.5: {5, 6, "Tone", 7, 1}
}

employee.pop("age", None)
print("Removed 'age' key:", employee)
# Out:
# Removed 'age' key: {'name': 'A', 'type': {'developer': ['iOS', 'android']}, 'permanent': True, 'salary': 30000, 100: (1, 2, 3), 4.5: {1, 5, 6, 7, 'Tone'}}

# %% [markdown]
# **6**

# %%
employee = {
    "name": "A",
    "age": 40,
    "type": {"developer": ["iOS", "android"]},
    "permanent": True,
    "salary": 30000,
    100: (1, 2, 3),
    4.5: {5, 6, "Tone", 7, 1}
}

print("Keys of the dictionary:", employee.keys())
print("Values of the dictionary:", employee.values())
print("Items of the dictionary:", employee.items())
# Out:
# Keys of the dictionary: dict_keys(['name', 'age', 'type', 'permanent', 'salary', 100, 4.5])
# Values of the dictionary: dict_values(['A', 40, {'developer': ['iOS', 'android']}, True, 30000, (1, 2, 3), {1, 5, 6, 7, 'Tone'}])
# Items of the dictionary: dict_items([('name', 'A'), ('age', 40), ('type', {'developer': ['iOS', 'android']}), ('permanent', True), ('salary', 30000), (100, (1, 2, 3)), (4.5, {1, 5, 6, 7, 'Tone'})])

# %% [markdown]
# **7**

# %%
employee = {
    "name": "A",
    "age": 40,
    "type": {"developer": ["iOS", "android"]},
    "permanent": True,
    "salary": 30000,
    100: (1, 2, 3),
    4.5: {5, 6, "Tone", 7, 1}
}

print("Iterating through dictionary:")
for key, value in employee.items():
    print(f"{key}: {value}")
# Out:
# Iterating through dictionary:
# name: A
# age: 40
# type: {'developer': ['iOS', 'android']}
# permanent: True
# salary: 30000
# 100: (1, 2, 3)
# 4.5: {1, 5, 6, 7, 'Tone'}

# %% [markdown]
# ## **String**

# %% [markdown]
# **1**

# %%
a = "hello"
b = "b2b2b2"
c = "3g3g"
d = a + b + c

print("Concatenated string:", d)
# Out:
# Concatenated string: hellob2b2b23g3g

# %% [markdown]
# **2**

# %%
a = "hello"
b = "b2b2b2"
c = "3g3g"
d = a + b + c

length_d = len(d)
print("Length of d:", length_d)
print("Last character of d:", d[-3])
# Out:
# Length of d: 15
# Last character of d: g

# %% [markdown]
# **3**

# %%
a = "hello"
b = "b2b2b2"
c = "3g3g"
d = a + b + c

a2_present = "a2" in d
print('"a2" is present in d:', a2_present)
# Out:
# "a2" is present in d: False

# %% [markdown]
# **4**

# %%
a = "hello"
b = "b2b2b2"
c = "3g3g"
d = a + b + c

print("Uppercase:", d.upper())
print("Lowercase:", d.lower())
print("Titlecase:", d.title())
print("Stripped:", d.strip())
print("Is digit:", d.isdigit())
print('Find "3g":', d.find("3g"))
print("Capitalize:", d.capitalize())
print("Alphanumeric:", d.isalnum())
print('Count "b2":', d.count("b2"))
print("Split:", d.split())
print("Swapcase:", d.swapcase())
print("Left strip:", d.lstrip("h"))
print('Replace "hello" with "python":', d.replace("hello", "python"))
# Out:
# Uppercase: HELLOB2B2B23G3G
# Lowercase: hellob2b2b23g3g
# Titlecase: Hellob2B2B23G3G
# Stripped: hellob2b2b23g3g
# Is digit: False
# Find "3g": 11
# Capitalize: Hellob2b2b23g3g
# Alphanumeric: True
# Count "b2": 3
# Split: ['hellob2b2b23g3g']
# Swapcase: HELLOB2B2B23G3G
# Left strip: ellob2b2b23g3g
# Replace "hello" with "python": pythonb2b2b23g3g
